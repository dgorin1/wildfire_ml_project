# %%
# Out:
# Connecting to Copernicus DEM Zarr...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 61
#      58     print("Update your pipeline code to point to this file path.")
#      60 if __name__ == "__main__":
# ---> 61     main()
#
# Cell In[3], line 16, in main()
#      12 print(f"Connecting to Copernicus DEM Zarr...")
#      14 # 1. Open the Remote Zarr
#      15 # We use mask_and_scale=True so we get actual Elevation floats (meters), not raw integers
# ---> 16 ds = xr.open_dataset(
#      17     "https://data.earthdatahub.destine.eu/copernicus-dem/GLO-30-v0.zarr",
#      18     storage_options={"client_kwargs":{"trust_env":True}},
#      19     chunks={}, # Load lazily
#      20     engine="zarr",
#      21     decode_coords="all",
#      22     mask_and_scale=True
#      23 )
#      25 # 2. Identify the Data Variable
# ...
